# %%
# Modules & set directory

import os
os.chdir("C:/Users/jaspe/PycharmProjects/phonorm")

from phonorm.utilities import create_mapping, tensor_from_pair, one_hot_encode, decode_from_ohe
from phonorm.tests import check_ohe
from phonorm.evaluate import plot_model_history, decode_sequence, evaluate_bleu
from keras.optimizers import Adam
from phonorm.Seq2Seq import Seq2Seq
import numpy as np
import random
# Out:
# Using TensorFlow backend.

# %%
# Load preprocessed data
pairs = np.load("data/preprocessed/cmudict_multichar_train.npy")

# %%
# Create mapping
input_lang, output_lang = create_mapping("input", "output", pairs, split = True)

# Sample training pairs (len(pairs) == entire training data set)
ml = len(pairs)
random.seed(245)
pairs_array = [random.choice(pairs) for i in range(ml)]

# Split array into input / output vectors
input_array = [pair[0] for pair in pairs_array]
output_array = [pair[1] for pair in pairs_array]

# %%
## One-hot encoding
encoder_in_ohe = one_hot_encode(input_array, input_lang)
decoder_in_ohe = one_hot_encode(output_array, output_lang, split = True)
decoder_out_ohe = one_hot_encode(output_array, output_lang, one_timestep_ahead=True, split = True)

# %%
## Check if one-hot encoding works properly by sampling 5 random pairs
check_ohe(pairs, input_lang, output_lang, 5, split = True)
# Out:
# decoded and 'target decoded' should be the same
#
# ---- Example 0
# Input: goatley, decoded: goatley
# Output:  g ow t l iy , decoded: gowtliy, target decoded: gowtliy
#
#
# ---- Example 1
# Input: russman, decoded: russman
# Output:  r ah s m ah n , decoded: rahsmahn, target decoded: rahsmahn
#
#
# ---- Example 2
# Input: desch, decoded: desch
# Output:  d eh sh , decoded: dehsh, target decoded: dehsh
#
#
# ---- Example 3
# Input: wad, decoded: wad
# Output:  w aa d , decoded: waad, target decoded: waad
#
#
# ---- Example 4
# Input: hanvey, decoded: hanvey
# Output:  hh ae n v iy , decoded: hhaenviy, target decoded: hhaenviy

# %% [markdown]
# ## Training the model

# %%
## Try
phonorm = Seq2Seq(512, input_lang, output_lang)

## Encoder
phonorm.Encoder(input_lang.n_chars, dropout_prop=0.1, recurrent_dropout_prop=0.1)

## Decoder
phonorm.Decoder(output_lang.n_chars, dropout_prop=0.1, recurrent_dropout_prop=0.1)

# %%
## Compile the phonorm model
phonorm.compile_model(print_summary = True, optimizer = Adam(lr=0.005, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           (None, None, 34)     0
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) [(None, 1024), (None 2240512     input_13[0][0]
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, None, 43)     0
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1024)         0           bidirectional_5[0][1]
#                                                                  bidirectional_5[0][3]
#                                                                  bidirectional_5[0][2]
#                                                                  bidirectional_5[0][4]
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  [(None, None, 1024), 4374528     input_14[0][0]
#                                                                  concatenate_6[0][0]
#                                                                  concatenate_6[1][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, None, 43)     44075       lstm_10[0][0]
# ==================================================================================================
# Total params: 6,659,115
# Trainable params: 6,659,115
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
## Fit the model
phonorm.fit([encoder_in_ohe, decoder_in_ohe], decoder_out_ohe, batch_size = 128, epochs = 10)
# Out:
# Train on 115326 samples, validate on 6070 samples
# Epoch 1/10
# 115326/115326 [==============================] - 329s 3ms/step - loss: 0.1475 - val_loss: 0.0501
# Epoch 2/10
# 115326/115326 [==============================] - 322s 3ms/step - loss: 0.0479 - val_loss: 0.0332
# Epoch 3/10
# 115326/115326 [==============================] - 319s 3ms/step - loss: 0.0347 - val_loss: 0.0284
# Epoch 4/10
# 115326/115326 [==============================] - 321s 3ms/step - loss: 0.0286 - val_loss: 0.0250
# Epoch 5/10
# 115326/115326 [==============================] - 322s 3ms/step - loss: 0.0252 - val_loss: 0.0233
# Epoch 6/10
# 115326/115326 [==============================] - 322s 3ms/step - loss: 0.0227 - val_loss: 0.0220
# Epoch 7/10
# 115326/115326 [==============================] - 321s 3ms/step - loss: 0.0210 - val_loss: 0.0213
# Epoch 8/10
# 115326/115326 [==============================] - 322s 3ms/step - loss: 0.0195 - val_loss: 0.0209
# Epoch 9/10
# 115326/115326 [==============================] - 322s 3ms/step - loss: 0.0186 - val_loss: 0.0202
# Epoch 10/10
# 115326/115326 [==============================] - 322s 3ms/step - loss: 0.0174 - val_loss: 0.0196

# %%
# Predct
phonorm.predict("josje"), phonorm.predict("joasia")
# Out:
# ('jhows', 'jhowsyah')

# %%
# Save model
phonorm.save("models/cmudict/multichar_model_10EP_H512")
# Out:
# C:\Users\jaspe\Anaconda3\envs\phonorm\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_10 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'concatenate_6/concat:0' shape=(?, 1024) dtype=float32>, <tf.Tensor 'concatenate_6_1/concat:0' shape=(?, 1024) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '

# %%
phonorm.history

# %%
## Try
phonorm = Seq2Seq(512, input_lang, output_lang)
phonorm.load("models/cmudict/multichar_model_10EP_H512")

# %% [markdown]
# ## Evaluate the model on generic dev set
#
# The model should perform well in terms of [BLEU score](https://machinelearningmastery.com/calculate-bleu-score-for-text-python/). This is a measure of 'skill' for the model.

# %%
# Load dev set
devpairs = np.load("data/preprocessed/cmudict_multichar_dev.npy")

# %%
# Make predictions
inWords = [pair[0] for pair in devpairs]
outWords = [pair[1].replace(" ", "").replace("\n", "").replace("\t", "") for pair in devpairs]

# %%
bs_out = []
preds = []
for i, (inw, outw) in enumerate(devpairs):
    
    # Predict pronunciation
    pred = phonorm.predict(inw)
    preds.append(pred)
    
    # Print if random number > 0.99
    if random.random() > 0.99:
        ## Print
        print("--- Sample " + str(i))
        print("Word: " + inw)
        print("Ref: " + outw.replace(" ", "").replace("\n", "").replace("\t", ""))
        print("Pred: " + pred)
        print("\n")
    ## Calculate bleu score
    bs_out.append(evaluate_bleu(outw.replace(" ", "").replace("\n", "").replace("\t", ""), pred))
# Out:
# C:\Users\jaspe\Anaconda3\envs\phonorm\lib\site-packages\nltk\translate\bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# --- Sample 2
# Word: thighs
# Ref: thayz
# Pred: thayz
# C:\Users\jaspe\Anaconda3\envs\phonorm\lib\site-packages\nltk\translate\bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# --- Sample 191
# Word: sittner
# Ref: sihtner
# Pred: sihtner
#
#
# --- Sample 214
# Word: missal
# Ref: mihsahl
# Pred: mihsahl

# %%
# Bleu score
bs_1 = [bs[0].tolist()[0] for bs in bs_out]
bs_2 = [bs[1].tolist()[0] for bs in bs_out]
bs_3 = [bs[2].tolist()[0] for bs in bs_out]
bs_4 = [bs[3].tolist()[0] for bs in bs_out]

# %%
import matplotlib.pyplot as plt

## Plot bleu score function
def plot_bleu(data, index = 1):
    
    #%matplotlib inline
    plt.hist(data, normed=True, bins=15)
    plt.ylabel('BLEU score')
    plt.show()

# %%
print("1-grams avg: " + str(np.round(np.mean(bs_1),decimals=2)))
print("2-grams avg: " + str(np.round(np.mean(bs_2),decimals=2)))
print("3-grams avg: " + str(np.round(np.mean(bs_3),decimals=2)))
print("4-grams avg: " + str(np.round(np.mean(bs_4),decimals=2)))
plot_bleu(bs_1, 1)
plot_bleu(bs_2, 2)
plot_bleu(bs_3, 3)
plot_bleu(bs_3, 4)
# Out:
# 1-grams avg: 0.94
# 2-grams avg: 0.91
# 3-grams avg: 0.88
# 4-grams avg: 0.83
# C:\Users\jaspe\Anaconda3\envs\phonorm\lib\site-packages\matplotlib\axes\_axes.py:6510: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
## Are there words that are predicted to be the same but are not in actuality
from collections import Counter
c = Counter(preds)

## Is the sum of the predicted frequencies shorter than the dev set?
## If so, then there are duplicates.
## This is an issue because we know that the dev set has homophones
sum(c.values()) == len(devpairs)
# Out:
# True

# %%
## Save data
import pandas as pd
print("In: " + str(len(inWords)))
print("Out: " + str(len(outWords)))
print("Pred: " + str(len(preds)))
print("BS1: " + str(len(bs_1)))
print("BS2: " + str(len(bs_2)))
print("BS3: " + str(len(bs_3)))
print("BS4: " + str(len(bs_4)))

# To dict
data_dev = {
    "in":inWords,
    "out":outWords,
    "pred":preds,
    "bs1":bs_1,
    "bs2":bs_2,
    "bs3":bs_3,
    "bs4":bs_4
}

# To pandas df
data_dev = pd.DataFrame.from_dict(data_dev)

# To csv
data_dev.to_csv("writeup/multichar_dev.csv")
# Out:
# In: 400
# Out: 400
# Pred: 400
# BS1: 400
# BS2: 400
# BS3: 400
# BS4: 400

# %%
## Check out homophones set
devhmp = np.load("data/preprocessed/cmudict_multichar_homophone_dev.npy")
# Make predictions
inWords = [pair[0] for pair in devhmp]
outWords = [pair[1].replace(" ", "").replace("\n", "").replace("\t", "") for pair in devhmp]

# %%
## Get unique pronunciations
unique_pronuns = []
for hmp in devhmp:
    if hmp[1] in unique_pronuns:
        continue
    else:
        unique_pronuns.append(hmp[1])
        
print("Unique pronunciations: " + str(len(unique_pronuns)))
print("Homophones dev entries: " + str(len(devhmp)))
# Out:
# Unique pronunciations: 247
# Homophones dev entries: 614

# %%
equality = []
difficulty = []
inwords = []
outw = []
outw_pred = []
props_comp_to_outcome = []
props_comp_to_hmphones = []
props_all_equal = []
## For each unique pronunciation, predict
for pronun in unique_pronuns:
    
    ## Get entries where pronunciation is pronun
    pronun_entries_tmp = [entry for entry in devhmp if entry[1] == pronun]
    
    if len(pronun_entries_tmp) < 2:
        continue
    else:
        pronun_entries = pronun_entries_tmp
        
    ## Calculate equality score
    out_ref = pronun.replace(" ", "").replace("\t", "").replace("\n", "")
    
    ## Predict inwords
    out_pred = [phonorm.predict(pronun_entry[0]) for pronun_entry in pronun_entries]
    
    ## Add to list
    inwords.append("; ".join([inw[0] for inw in pronun_entries_tmp]))
    outw.append(out_ref)
    outw_pred.append("; ".join(out_pred))
    
    ## Equal to out?
    comp = [pred == out_ref for pred in out_pred]
    equality.append(comp)
    
    ## Proportion correct
    ## NB. also count instances where all entries are wrong but the same
    props_comp_to_outcome.append(np.sum(comp) / len(comp))
    
    ## Keep track of scores in a slighly different way --> look how many of the subgroups are equal to one another
    scores = []
    for grp in np.unique(out_pred):
        scores.append(np.sum([True if pr == grp else False for pr in out_pred]))
    
    props_comp_to_hmphones.append(scores[np.argmax(scores)] / sum(scores))
    
    ## All equal
    props_all_equal.append(int(np.all(comp)))
    
    ## If proportion low, then add to difficult
    if (np.sum(comp) / len(comp)) < 0.8:
        
        difficulty.append(
            {"ref":out_ref,
            "pred":out_pred,
            "inw":[entry[0] for entry in pronun_entries]}
        )

# %%
print("Equal to outcome: " + str(np.round(np.mean(props_comp_to_outcome), decimals=2)))
print("Highest subgroup: " + str(np.round(np.mean(props_comp_to_hmphones), decimals=2)))
print("All equal: " + str(np.round(np.sum(props_all_equal) / len(props_all_equal), decimals=2)))
# Out:
# Equal to outcome: 0.77
# Highest subgroup: 0.87
# All equal: 0.64

# %%
## Print
for i, difficult in enumerate(difficulty):
    
    print("----- Example " + str(i))
    print("Input: " + ", ".join(difficult["inw"]))
    print("Pred:  " + ", ".join(difficult["pred"]))
    print("True:  " + difficult["ref"])
    print("\n")
# Out:
# ----- Example 0
# Input: aleman, alleman
# Pred:  eylmahn, aelahmahn
# True:  eylmahn
#
#
# ----- Example 1
# Input: anno, ano
# Pred:  aenow, aanow
# True:  aenow
#
#
# ----- Example 2
# Input: arman, armen, armin, armon
# Pred:  aarmahn, aarmehn, aarmihn, aarmahn
# True:  aarmahn
#
#
# ----- Example 3
# Input: ayer, eyer, iyer
# Pred:  eyer, ayer, ayer
# True:  ayer
#
#
# ----- Example 4
# Input: balentine, ballentine
# Pred:  baelahntiyn, baelahntayn
# True:  baalehntiyniy
#
#
# ----- Example 5
# Input: barasch, barash
# Pred:  baarahsh, baarahsh
# True:  baerahsh
#
#
# ----- Example 6
# Input: barone, barrone
# Pred:  berown, baarowniy
# True:  berown
#
#
# ----- Example 7
# Input: biron, byron
# Pred:  bayraan, bayrahn
# True:  bayrahn
#
#
# ----- Example 8
# Input: boan, boehne, boen, bohn, bohne, bone, bown, bowne
# Pred:  bown, bown, bown, baan, bown, bown, bawn, bown
# True:  bown
#
#
# ----- Example 9
# Input: bohnet, bonnett
# Pred:  bowniht, baaniht
# True:  baaniht
#
#
# ----- Example 10
# Input: carolina, karolina
# Pred:  kehrowliynah, kehrowliynah
# True:  kehrahlaynah
#
#
# ----- Example 11
# Input: carron, karren
# Pred:  kehrahn, kehrahn
# True:  kaerahn
#
#
# ----- Example 12
# Input: charlene, charline, sharleen, sharlene
# Pred:  chaarliyn, chaarlayn, shaarliyn, shaarliyn
# True:  shaarliyn
#
#
# ----- Example 13
# Input: clouse, klaus
# Pred:  klaws, klaoz
# True:  klaws
#
#
# ----- Example 14
# Input: comet's, comets
# Pred:  kahmahts, kahmahts
# True:  kaamahts
#
#
# ----- Example 15
# Input: coppee, copy, kopy
# Pred:  kaapiy, kaapiy, kowpiy
# True:  kaapiy
#
#
# ----- Example 16
# Input: corespondent, correspondent
# Pred:  kaorspaandahnt, kaorahspaandahnt
# True:  kaorahspaandahnt
#
#
# ----- Example 17
# Input: crabill, krabill
# Pred:  kraabihl, kraabihl
# True:  kraebahl
#
#
# ----- Example 18
# Input: daya's, dias, diez
# Pred:  deyahz, diyaas, diyz
# True:  dayahz
#
#
# ----- Example 19
# Input: dhaharan, dhahran
# Pred:  dahhhaerahn, daahhahn
# True:  dahraan
#
#
# ----- Example 20
# Input: dolan, dolen, dollan
# Pred:  dowlahn, dowlahn, daalahn
# True:  dowlahn
#
#
# ----- Example 21
# Input: donaghue, donahoo, donohoo
# Pred:  daanahhhyuw, downahhhuw, daanahhhuw
# True:  daanahhhuw
#
#
# ----- Example 22
# Input: dumber, dummer
# Pred:  dahmber, dahmer
# True:  dahmer
#
#
# ----- Example 23
# Input: edoardo, eduardo
# Pred:  ehdaordow, ehdwaardow
# True:  ehdwaardow
#
#
# ----- Example 24
# Input: enloe, enlow, inlow
# Pred:  ehnlow, ehnlow, ihnlow
# True:  ihnlow
#
#
# ----- Example 25
# Input: examiners, examiners'
# Pred:  ihgzaemahnerz, ihgzaemahnerz
# True:  ihgzaemihnerz
#
#
# ----- Example 26
# Input: finlay, finley
# Pred:  fihnley, fihnliy
# True:  fihnliy
#
#
# ----- Example 27
# Input: gabrielsen, gabrielson
# Pred:  geybriyihlsahn, geybriyihlsahn
# True:  gaebriylsahn
#
#
# ----- Example 28
# Input: garmond, garmund
# Pred:  gaarmaend, gaarmahnd
# True:  gaarmahnd
#
#
# ----- Example 29
# Input: garret, gehret
# Pred:  gaeriht, gehriht
# True:  gehriht
#
#
# ----- Example 30
# Input: garrity, gerety
# Pred:  gaerihtiy, gihrahtiy
# True:  gehrihtiy
#
#
# ----- Example 31
# Input: geoff, jeff, jeffe
# Pred:  jhiyowf, jhehf, jhehf
# True:  jhehf
#
#
# ----- Example 32
# Input: german, jerman
# Pred:  germahn, jhermahn
# True:  jhermahn
#
#
# ----- Example 33
# Input: haagen, hogen, hoggan
# Pred:  hheyjhahn, hhowgahn, hhaagwaen
# True:  hhaagahn
#
#
# ----- Example 34
# Input: hail, haile, hale, heyl
# Pred:  hheyl, hheyl, hheyl, hhayl
# True:  hheyl
#
#
# ----- Example 35
# Input: halgren, hallgren
# Pred:  hhaelgrehn, hhaolgrehn
# True:  hhaelgrehn
#
#
# ----- Example 36
# Input: heinecke, heinicke, hynek
# Pred:  hhaynihkiy, hhaynihk, hhihnehk
# True:  hhaynihk
#
#
# ----- Example 37
# Input: isackson, isaksen, isakson
# Pred:  ihsaaksahn, ihsaaksahn, ihsaaksahn
# True:  ihsahksahn
#
#
# ----- Example 38
# Input: kearn, kern, kirn
# Pred:  kihrn, kern, kern
# True:  kern
#
#
# ----- Example 39
# Input: kearney, kearny, kerney
# Pred:  kihrniy, kerniy, kerniy
# True:  kerniy
#
#
# ----- Example 40
# Input: keathley, keithley, keithly
# Pred:  kiythliy, kaythliy, kiythliy
# True:  kiythliy
#
#
# ----- Example 41
# Input: lauren, loren
# Pred:  laorihn, laorahn
# True:  laorahn
#
#
# ----- Example 42
# Input: leavitt, levett, levit, levitt, levitte
# Pred:  liyviht, lehviht, lehviht, lehviht, lihviht
# True:  lehviht
#
#
# ----- Example 43
# Input: leeuwen, lewan, luane
# Pred:  luwyuwn, luwaan, lweyn
# True:  luwahn
#
#
# ----- Example 44
# Input: lohse, los
# Pred:  lows, laos
# True:  lows
#
#
# ----- Example 45
# Input: machinists, machinists'
# Pred:  maekahnahsts, maekahnahsts
# True:  mahshiynihsts
#
#
# ----- Example 46
# Input: masci, massey, massi, massie
# Pred:  maasiy, maesiy, maesiy, maesiy
# True:  maesiy
#
#
# ----- Example 47
# Input: mathes, mathis, matthis
# Pred:  meydhz, maethihs, maethihs
# True:  maethihs
#
#
# ----- Example 48
# Input: mccracken, mccrackin
# Pred:  mahkraekahn, mahkraekihn
# True:  mahkraekahn
#
#
# ----- Example 49
# Input: mcelrath, mcelreath, mcilrath
# Pred:  maekahlraeth, maekahliyehth, maekahlthaath
# True:  maekahlraeth
#
#
# ----- Example 50
# Input: mckinsey, mckinzie
# Pred:  mahkihnsiy, mahkihnziy
# True:  mahkihnziy
#
#
# ----- Example 51
# Input: mcmahan, mcmahen
# Pred:  mahkmeyahn, mahkmeyahn
# True:  mahkmeyhhahn
#
#
# ----- Example 52
# Input: mean, mein, meine, mien
# Pred:  miyn, meyn, meyn, miyn
# True:  miyn
#
#
# ----- Example 53
# Input: millimeters, millimetres
# Pred:  mihlihmiyterz, mihlihmehterz
# True:  mihlahmiyterz
#
#
# ----- Example 54
# Input: mortensen, mortenson
# Pred:  maortehnsahn, maortehnsahn
# True:  maortihnsahn
#
#
# ----- Example 55
# Input: naito, nato
# Pred:  neytow, naatow
# True:  neytow
#
#
# ----- Example 56
# Input: nichole, nicole, nicolle
# Pred:  nihhhowl, nihkowliy, nihkahl
# True:  nihkowl
#
#
# ----- Example 57
# Input: nicor, nycor
# Pred:  nihkaor, naykaor
# True:  naykaor
#
#
# ----- Example 58
# Input: nolie, nolley
# Pred:  nowliy, naaliy
# True:  naaliy
#
#
# ----- Example 59
# Input: norell, norrell
# Pred:  naorahl, naoreyl
# True:  naorahl
#
#
# ----- Example 60
# Input: panko, pankow
# Pred:  paengkow, paengkaw
# True:  paengkow
#
#
# ----- Example 61
# Input: peaked, peeked, piqued
# Pred:  piykt, piykt, piykd
# True:  piykt
#
#
# ----- Example 62
# Input: perret, perrett, perritt
# Pred:  perrey, perreht, pehriht
# True:  perriht
#
#
# ----- Example 63
# Input: pizza's, pizzas
# Pred:  pihzahz, pihzahz
# True:  piytsahz
#
#
# ----- Example 64
# Input: plaino, plano
# Pred:  pleynow, plaanow
# True:  pleynow
#
#
# ----- Example 65
# Input: problem's, problems
# Pred:  praablehmz, praablehmz
# True:  praablahmz
#
#
# ----- Example 66
# Input: prochaska, prohaska
# Pred:  prahshaaskah, prowhhaeskah
# True:  prahhhaaskah
#
#
# ----- Example 67
# Input: rapist's, rapists
# Pred:  raepihsts, raepihsts
# True:  reypihsts
#
#
# ----- Example 68
# Input: reiter, reitter, righter, riter, writer
# Pred:  riyter, riyter, rayter, rayter, rayter
# True:  rayter
#
#
# ----- Example 69
# Input: renaud, reneau, ryno
# Pred:  rihnaod, rihnow, riynow
# True:  rihnow
#
#
# ----- Example 70
# Input: renfro, renfroe
# Pred:  rehnfrow, rehnfruw
# True:  rehnfrow
#
#
# ----- Example 71
# Input: salable, saleable
# Pred:  seylahbahl, sahliyahbahl
# True:  seylahbahl
#
#
# ----- Example 72
# Input: sao, sow
# Pred:  saw, sow
# True:  saw
#
#
# ----- Example 73
# Input: seeks, seix, sikhs
# Pred:  siyks, siyks, sihks
# True:  siyks
#
#
# ----- Example 74
# Input: seoul, sohl, sole, soul, sowle
# Pred:  sowl, sowl, sowl, sawl, sawl
# True:  sowl
#
#
# ----- Example 75
# Input: sophie, sophy
# Pred:  saafiy, saafiy
# True:  sowfiy
#
#
# ----- Example 76
# Input: species, species'
# Pred:  spiysiyz, spiysiyz
# True:  spiyshiyz
#
#
# ----- Example 77
# Input: suites, sweets
# Pred:  suwts, swiyts
# True:  swiyts
#
#
# ----- Example 78
# Input: sweats, swetz
# Pred:  swiyts, swehts
# True:  swehts
#
#
# ----- Example 79
# Input: tallant, tallent
# Pred:  taelahnt, taelahnt
# True:  taalahnt
#
#
# ----- Example 80
# Input: taverna's, tavernas
# Pred:  taavehrnahz, tahvernahz
# True:  taavehrnahz
#
#
# ----- Example 81
# Input: vaca, vacca
# Pred:  vaakah, vaekah
# True:  vaekah
#
#
# ----- Example 82
# Input: vancampen, vankampen
# Pred:  vaenkaempihn, vaenkaempihn
# True:  vaenkaempahn
#
#
# ----- Example 83
# Input: vasquez, vazquez
# Pred:  vaeskwehz, vaaskwehz
# True:  vaeskehz
#
#
# ----- Example 84
# Input: veers, viers
# Pred:  vihrz, vayerz
# True:  vihrz
#
#
# ----- Example 85
# Input: wank, wanke
# Pred:  waengk, waengk
# True:  waangk
#
#
# ----- Example 86
# Input: yandell, yandle
# Pred:  yaendehl, yaendahl
# True:  yaendahl

# %%
# To pandas dataframe
import pandas as pd

data_dev_hmp = {
    "in":inwords,
    "pred": outw_pred,
    "out":outw,
    "equality":equality,
    "props_comp_to_outcome":props_comp_to_outcome,
    "props_comp_to_hmphones":props_comp_to_hmphones,
    "props_all_equal":props_all_equal
}

# To pandas df
data_dev = pd.DataFrame.from_dict(data_dev_hmp)

# To csv
data_dev.to_csv("writeup/multichar_dev_hmp.csv")

# %% [markdown]
# ## Misspelled words

# %%
## Load data
misp = np.load('data/preprocessed/wikipedia_misspelled.npy')

# %%
badpreds = []
goodpreds = []
tp = 0
fp = 0
tn = 0
fn = 0
wrong = []
for (pair, score) in misp:
    
    # Predict pronunciation
    try:
        bpred = phonorm.predict(pair[0])
        gpred = phonorm.predict(pair[1])
    except:
        continue
    
    badpreds.append(bpred)
    goodpreds.append(gpred)
    
    # If bpred and gpred are the same and score == 1 (pronunciation of the words is the same), then add to accuracy
    if bpred == gpred:
        are_equal = True
    else:
        are_equal = False
    
    if score == 0:
        if are_equal == False:
            tn += 1
        else:
            fn += 1
            wrong.append([pair, bool(score), [bpred, gpred], True])
    else:
        if are_equal:
            tp += 1
        else:
            fp += 1
            wrong.append([pair, bool(score), [bpred, gpred], False])
    
    # Print if random number > 0.99
    if random.random() > 0.5:
        ## Print
        print("----------")
        print("Misspelled: " + pair[0] + ", Pred: " + bpred)
        print("Correct: " + pair[1] + ", Pred: " + gpred)
        print("\n")
# Out:
# ----------
# Misspelled: acclimitization, Pred: ahklihmahtahzeyshahn
# Correct: acclimatization, Pred: aeklihmahtahzeyshahn
#
#
# ----------
# Misspelled: calulated, Pred: kaelyahleytahd
# Correct: calculated, Pred: kaelkyahleytahd
#
#
# ----------
# Misspelled: fullfilled, Pred: fuhlfihld
# Correct: fulfilled, Pred: fuhlfihld
#
#
# ----------
# Misspelled: activly, Pred: aektihvliy
# Correct: actively, Pred: aektihvliy
#
#
# ----------
# Misspelled: seperatism, Pred: sehperahtihzahm
# Correct: separatism, Pred: sehperahtihzahm
#
#
# ----------
# Misspelled: controveries, Pred: kahntrowveriyz
# Correct: controversies, Pred: kaantrahversiyz
#
#
# ----------
# Misspelled: druming, Pred: druwmihng
# Correct: drumming, Pred: drahmihng
#
#
# ----------
# Misspelled: reponsible, Pred: riypaansahbahl
# Correct: responsible, Pred: riyspaansahbahl
#
#
# ----------
# Misspelled: technnology, Pred: tehknaalahjhiy
# Correct: technology, Pred: tehknaalahjhiy
#
#
# ----------
# Misspelled: celcius, Pred: sehlsiyihs
# Correct: celsius, Pred: sehlsiyihs
#
#
# ----------
# Misspelled: temperarily, Pred: tehmperehrahliy
# Correct: temporarily, Pred: tehmperehrahliy
#
#
# ----------
# Misspelled: technitian, Pred: tehknihshahn
# Correct: technician, Pred: tehknihshahn
#
#
# ----------
# Misspelled: ceromony, Pred: sehrahmowniy
# Correct: ceremony, Pred: sehrahmowniy
#
#
# ----------
# Misspelled: agricuture, Pred: ahgrihkyuwcher
# Correct: agriculture, Pred: aegrahkahlcher
#
#
# ----------
# Misspelled: asside, Pred: ahsayd
# Correct: aside, Pred: ahsayd
#
#
# ----------
# Misspelled: immediatly, Pred: ihmiydiyahtliy
# Correct: immediately, Pred: ihmiydiyahtliy
#
#
# ----------
# Misspelled: bcak, Pred: baek
# Correct: back, Pred: baek
#
#
# ----------
# Misspelled: alledge, Pred: aelihjh
# Correct: allege, Pred: ahlehjh
#
#
# ----------
# Misspelled: transistion, Pred: traensihsahn
# Correct: transition, Pred: traenzihshahn
#
#
# ----------
# Misspelled: ppublisher, Pred: pahbahlsher
# Correct: publisher, Pred: pahblihsher
#
#
# ----------
# Misspelled: hvaing, Pred: eyvihng
# Correct: having, Pred: hheyvihng
#
#
# ----------
# Misspelled: yeasr, Pred: yiyzer
# Correct: years, Pred: yihrz
#
#
# ----------
# Misspelled: fundametals, Pred: fahndahmehtahlz
# Correct: fundamentals, Pred: fahndahmehntahlz
#
#
# ----------
# Misspelled: renedered, Pred: rehnihderd
# Correct: rende, Pred: rehnd
#
#
# ----------
# Misspelled: heterogenous, Pred: hhehterahjhahnahs
# Correct: heterogeneous, Pred: hhehterahjhiyniyahs
#
#
# ----------
# Misspelled: decendant, Pred: dahsehndahnt
# Correct: descendant, Pred: dihsehndahnt
#
#
# ----------
# Misspelled: successully, Pred: sahksehsahliy
# Correct: successfully, Pred: sahksehsfahliy
#
#
# ----------
# Misspelled: eiter, Pred: ayter
# Correct: either, Pred: aydher
#
#
# ----------
# Misspelled: unsuccesfully, Pred: ahnsahksehsfahliy
# Correct: unsuccessfully, Pred: ahnsahksehsfahliy
#
#
# ----------
# Misspelled: rebiulding, Pred: riybihldihng
# Correct: rebuilding, Pred: riybihldihng
#
#
# ----------
# Misspelled: furuther, Pred: ferahther
# Correct: further, Pred: ferdher
#
#
# ----------
# Misspelled: algebraical, Pred: aelgahbrihkahl
# Correct: algebraic, Pred: aelgahbreyk
#
#
# ----------
# Misspelled: moeny, Pred: mowniy
# Correct: money, Pred: mowniy
#
#
# ----------
# Misspelled: sufficently, Pred: sahfihstahntliy
# Correct: sufficiently, Pred: sahfihshahntliy
#
#
# ----------
# Misspelled: scinece, Pred: sihniys
# Correct: science, Pred: sayahns
#
#
# ----------
# Misspelled: omlette, Pred: owmleht
# Correct: omelette, Pred: aamleht
#
#
# ----------
# Misspelled: compulsery, Pred: kahmpahlseriy
# Correct: compulsory, Pred: kahmpahlseriy
#
#
# ----------
# Misspelled: opression, Pred: owprehshahn
# Correct: oppression, Pred: ahprehshahn
#
#
# ----------
# Misspelled: aplied, Pred: ahplayd
# Correct: applied, Pred: ahplayd
#
#
# ----------
# Misspelled: subtances, Pred: sahbtahnsihz
# Correct: substances, Pred: sahbstahnsihz
#
#
# ----------
# Misspelled: irrelevent, Pred: ihrehlahvahnt
# Correct: irrelevant, Pred: ihrehlahvahnt
#
#
# ----------
# Misspelled: prestigous, Pred: prehstihgahs
# Correct: prestigious, Pred: prehstihjhihs
#
#
# ----------
# Misspelled: adminstrator, Pred: aedmihnstreyter
# Correct: administrator, Pred: aedmihnihstreyter
#
#
# ----------
# Misspelled: whta, Pred: wiytah
# Correct: what, Pred: waht
#
#
# ----------
# Misspelled: provinicial, Pred: praavahnihshahl
# Correct: provincial, Pred: praavihnshahl
#
#
# ----------
# Misspelled: remembrence, Pred: rihmehmbrahns
# Correct: remembrance, Pred: rihmehmbrahns
#
#
# ----------
# Misspelled: habaeus, Pred: hhaebayihs
# Correct: habeas, Pred: hhaebiyahs
#
#
# ----------
# Misspelled: payed, Pred: peyd
# Correct: paid, Pred: peyd
#
#
# ----------
# Misspelled: abbout, Pred: aebawt
# Correct: about, Pred: ahbawt
#
#
# ----------
# Misspelled: excange, Pred: ihkskeynjh
# Correct: exchange, Pred: ihkscheynjh
#
#
# ----------
# Misspelled: strenght, Pred: strehngt
# Correct: strength, Pred: strehngkth

# %%
# Metrics
acc = (tp + tn) / (tp + fp + tn + fn)
sens = tp / (tp + fn)
spec = tn / (fn + tn)
f1 = 2*(sens * spec) / (sens + spec)
#-----

print("Accuracy: " + str(acc))
print("Sensitivity: " + str(sens))
print("Specificity: " + str(spec))
print("F1: " + str(f1))
# Out:
# Accuracy: 0.83
# Sensitivity: 0.7741935483870968
# Specificity: 0.8939393939393939
# F1: 0.8297685320832112

# %%
wrong
# Out:
# [[['impecabbly', 'impeccably'],
#   True,
#   ['ihmpahkahbliy', 'ihmpehkahbliy'],
#   False],
#  [['harasment', 'harassment'], False, ['hheraesmahnt', 'hheraesmahnt'], True],
#  [['likelyhood', 'likelihood'], True, ['laykliyhhuhd', 'layklihhhuhd'], False],
#  [['technnology', 'technology'],
#   False,
#   ['tehknaalahjhiy', 'tehknaalahjhiy'],
#   True],
#  [['temperarily', 'temporarily'],
#   False,
#   ['tehmperehrahliy', 'tehmperehrahliy'],
#   True],
#  [['greatfully', 'gratefully'], True, ['griytfahliy', 'greytfahliy'], False],
#  [['bcak', 'back'], False, ['baek', 'baek'], True],
#  [['transistion', 'transition'],
#   True,
#   ['traensihsahn', 'traenzihshahn'],
#   False],
#  [['contraversy', 'controversy'],
#   True,
#   ['kaantrahvehriy', 'kaantrahversiy'],
#   False],
#  [['decendant', 'descendant'], True, ['dahsehndahnt', 'dihsehndahnt'], False],
#  [['unsuccesfully', 'unsuccessfully'],
#   False,
#   ['ahnsahksehsfahliy', 'ahnsahksehsfahliy'],
#   True],
#  [['rebiulding', 'rebuilding'], False, ['riybihldihng', 'riybihldihng'], True],
#  [['moeny', 'money'], False, ['mowniy', 'mowniy'], True],
#  [['addopted', 'adopted'], True, ['ahdaaptahd', 'ahdaaptihd'], False],
#  [['comback', 'comeback'], True, ['kaambaek', 'kahmbaek'], False],
#  [['ghandi', 'gandhi'], True, ['gaendiy', 'gaandiy'], False],
#  [['abbout', 'about'], True, ['aebawt', 'ahbawt'], False]]
